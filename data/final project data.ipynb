# %% [markdown]
# ## Data Exploration

# %%
# different imports

import pandas as pd
import numpy as np
from tabulate import tabulate

# %%
# reading csv file 

df = pd.read_csv('student_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 60 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1044 non-null   int64
#  1   age                1044 non-null   float64
#  2   Medu               1044 non-null   int64
#  3   Fedu               1044 non-null   int64
#  4   traveltime         1044 non-null   int64
#  5   studytime          1044 non-null   int64
#  6   failures           1044 non-null   int64
#  7   famrel             1044 non-null   float64
#  8   freetime           1044 non-null   float64
#  9   goout              1044 non-null   float64
#  10  Dalc               1044 non-null   int64
#  11  Walc               1044 non-null   float64
#  12  health             1044 non-null   float64
#  13  absences           1044 non-null   float64
#  14  G3                 1044 non-null   int64
#  15  school_GP          1044 non-null   int64
#  16  school_MS          1044 non-null   int64
#  17  class_mat          1044 non-null   int64
#  18  class_por          1044 non-null   int64
#  19  sex_F              1044 non-null   int64
#  20  sex_M              1044 non-null   int64
#  21  address_R          1044 non-null   int64
#  22  address_U          1044 non-null   int64
#  23  famsize_GT3        1044 non-null   int64
#  24  famsize_LE3        1044 non-null   int64
#  25  Pstatus_A          1044 non-null   int64
#  26  Pstatus_T          1044 non-null   int64
#  27  Mjob_at_home       1044 non-null   int64
#  28  Mjob_health        1044 non-null   int64
#  29  Mjob_other         1044 non-null   int64
#  30  Mjob_services      1044 non-null   int64
#  31  Mjob_teacher       1044 non-null   int64
#  32  Fjob_at_home       1044 non-null   int64
#  33  Fjob_health        1044 non-null   int64
#  34  Fjob_other         1044 non-null   int64
#  35  Fjob_services      1044 non-null   int64
#  36  Fjob_teacher       1044 non-null   int64
#  37  reason_course      1044 non-null   int64
#  38  reason_home        1044 non-null   int64
#  39  reason_other       1044 non-null   int64
#  40  reason_reputation  1044 non-null   int64
#  41  guardian_father    1044 non-null   int64
#  42  guardian_mother    1044 non-null   int64
#  43  guardian_other     1044 non-null   int64
#  44  schoolsup_no       1044 non-null   int64
#  45  schoolsup_yes      1044 non-null   int64
#  46  famsup_no          1044 non-null   int64
#  47  famsup_yes         1044 non-null   int64
#  48  paid_no            1044 non-null   int64
#  49  paid_yes           1044 non-null   int64
#  50  activities_no      1044 non-null   int64
#  51  activities_yes     1044 non-null   int64
#  52  nursery_no         1044 non-null   int64
#  53  nursery_yes        1044 non-null   int64
#  54  higher_no          1044 non-null   int64
#  55  higher_yes         1044 non-null   int64
#  56  internet_no        1044 non-null   int64
#  57  internet_yes       1044 non-null   int64
#  58  romantic_no        1044 non-null   int64
#  59  romantic_yes       1044 non-null   int64
# dtypes: float64(7), int64(53)
# memory usage: 489.5 KB

# %%
# headers of features

#headers = ["test preparation course","math score","reading score","writing score", "gender","race/ethnicity","parental level of education",
#"lunch"]

# %%
# prints out the object feature test prep course and converts to boolean 

#printTrue = df['test preparation course'] = df['test preparation course'].replace(['completed'], True)
#printFalse = df['test preparation course'] = df['test preparation course'].replace(['none'], False)

# %%
#df['test preparation course'].astype('int8')

# drop ID
#df = df.iloc[: , 1:]

# %% [markdown]
# ### One-Hot Encoded Data

# %%
# one-hot encoded data: gender, ethnicity, education, lunch

one_hot_encoded_data = pd.get_dummies(df, columns = ['school', 'class', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic'])
print(tabulate(one_hot_encoded_data, headers = "keys", tablefmt='fancy_grid'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/miskiabdirizak/Documents/GitHub/DS_exam_evaluation/data/final project data.ipynb Cell 8 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/miskiabdirizak/Documents/GitHub/DS_exam_evaluation/data/final%20project%20data.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> # one-hot encoded data: gender, ethnicity, education, lunch
# ----> <a href='vscode-notebook-cell:/Users/miskiabdirizak/Documents/GitHub/DS_exam_evaluation/data/final%20project%20data.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> one_hot_encoded_data = pd.get_dummies(df, columns = ['school', 'class', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic'])
#       <a href='vscode-notebook-cell:/Users/miskiabdirizak/Documents/GitHub/DS_exam_evaluation/data/final%20project%20data.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> print(tabulate(one_hot_encoded_data, headers = "keys", tablefmt='fancy_grid'))
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:931, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     929     raise TypeError("Input must be a list-like for parameter `columns`")
#     930 else:
# --> 931     data_to_encode = data[columns]
#     933 # validate prefixes and separator to avoid silently dropping cols
#     934 def check_len(item, name):
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['school', 'class', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob',\n       'Fjob', 'reason', 'guardian', 'paid', 'activities', 'nursery', 'higher',\n       'internet', 'romantic'],\n      dtype='object')] are in the [columns]"

# %% [markdown]
# ### Missing Values and Outliers

# %% [markdown]
# ### Normalization

# %%
# normalize the code
from sklearn.preprocessing import MinMaxScaler

df_sklearn = df.copy()

columns = 'age'
df_sklearn[columns] = MinMaxScaler().fit_transform(np.array(df_sklearn[columns]).reshape(-1,1))

columns2 = 'famrel'
df_sklearn[columns2] = MinMaxScaler().fit_transform(np.array(df_sklearn[columns2]).reshape(-1,1))

columns3 = 'freetime'
df_sklearn[columns3] = MinMaxScaler().fit_transform(np.array(df_sklearn[columns3]).reshape(-1,1))

columns4 = 'goout'
df_sklearn[columns4] = MinMaxScaler().fit_transform(np.array(df_sklearn[columns4]).reshape(-1,1))

columns5 = 'Walc'
df_sklearn[columns5] = MinMaxScaler().fit_transform(np.array(df_sklearn[columns5]).reshape(-1,1))

columns6 = 'health'
df_sklearn[columns6] = MinMaxScaler().fit_transform(np.array(df_sklearn[columns6]).reshape(-1,1))

columns7 = 'absences'
df_sklearn[columns7] = MinMaxScaler().fit_transform(np.array(df_sklearn[columns7]).reshape(-1,1))

# view normalized data  
display(df_sklearn)
# Out:
#      school class sex       age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0        GP   mat   F  0.428571       U     GT3       A     4     4   at_home
# 1        GP   mat   F  0.285714       U     GT3       T     1     1   at_home
# 2        GP   mat   F  0.000000       U     LE3       T     1     1   at_home
# 3        GP   mat   F  0.000000       U     GT3       T     4     2    health
# 4        GP   mat   F  0.142857       U     GT3       T     3     3     other
# ...     ...   ...  ..       ...     ...     ...     ...   ...   ...       ...
# 1039     MS   por   F  0.571429       R     GT3       T     2     3  services
# 1040     MS   por   F  0.428571       U     LE3       T     3     1   teacher
# 1041     MS   por   F  0.428571       U     GT3       T     1     1     other
# 1042     MS   por   M  0.285714       U     LE3       T     3     1  services
# 1043     MS   por   M  0.428571       R     LE3       T     3     2  services
#
#       ... internet romantic famrel  freetime  goout  Dalc  Walc health  \
# 0     ...       no       no   0.75      0.50   0.75     1  0.00   0.50
# 1     ...      yes       no   1.00      0.50   0.50     1  0.00   0.50
# 2     ...      yes       no   0.75      0.50   0.25     2  0.50   0.50
# 3     ...      yes      yes   0.50      0.25   0.25     1  0.00   1.00
# 4     ...       no       no   0.75      0.50   0.25     1  0.25   1.00
# ...   ...      ...      ...    ...       ...    ...   ...   ...    ...
# 1039  ...      yes       no   1.00      0.75   0.25     1  0.25   1.00
# 1040  ...      yes       no   0.75      0.50   0.75     1  0.00   0.00
# 1041  ...       no       no   0.00      0.00   0.00     1  0.00   1.00
# 1042  ...      yes       no   0.25      0.75   1.00     3  0.75   0.25
# 1043  ...      yes       no   0.75      0.75   0.00     3  0.75   1.00
#
#       absences  G3
# 0     0.080000   6
# 1     0.053333   6
# 2     0.133333  10
# 3     0.026667  15
# 4     0.053333  10
# ...        ...  ..
# 1039  0.053333  10
# 1040  0.053333  16
# 1041  0.080000   9
# 1042  0.080000  10
# 1043  0.053333  11
#
# [1044 rows x 32 columns]

# %%
# turn categorical info into binary

binary1 = pd.get_dummies(df_sklearn)
binary1.to_csv('student_data.csv')

display (binary1)
# Out:
#            age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     0.428571     4     4           2          2         0    0.75      0.50
# 1     0.285714     1     1           1          2         0    1.00      0.50
# 2     0.000000     1     1           1          2         3    0.75      0.50
# 3     0.000000     4     2           1          3         0    0.50      0.25
# 4     0.142857     3     3           1          2         0    0.75      0.50
# ...        ...   ...   ...         ...        ...       ...     ...       ...
# 1039  0.571429     2     3           1          3         1    1.00      0.75
# 1040  0.428571     3     1           1          2         0    0.75      0.50
# 1041  0.428571     1     1           2          2         0    0.00      0.00
# 1042  0.285714     3     1           2          1         0    0.25      0.75
# 1043  0.428571     3     2           3          1         0    0.75      0.75
#
#       goout  Dalc  ...  activities_no  activities_yes  nursery_no  \
# 0      0.75     1  ...              1               0           0
# 1      0.50     1  ...              1               0           1
# 2      0.25     2  ...              1               0           0
# 3      0.25     1  ...              0               1           0
# 4      0.25     1  ...              1               0           0
# ...     ...   ...  ...            ...             ...         ...
# 1039   0.25     1  ...              0               1           1
# 1040   0.75     1  ...              1               0           0
# 1041   0.00     1  ...              0               1           0
# 1042   1.00     3  ...              1               0           1
# 1043   0.00     3  ...              1               0           1
#
#       nursery_yes  higher_no  higher_yes  internet_no  internet_yes  \
# 0               1          0           1            1             0
# 1               0          0           1            0             1
# 2               1          0           1            0             1
# 3               1          0           1            0             1
# 4               1          0           1            1             0
# ...           ...        ...         ...          ...           ...
# 1039            0          0           1            0             1
# 1040            1          0           1            0             1
# 1041            1          0           1            1             0
# 1042            0          0           1            0             1
# 1043            0          0           1            0             1
#
#       romantic_no  romantic_yes
# 0               1             0
# 1               1             0
# 2               1             0
# 3               0             1
# 4               1             0
# ...           ...           ...
# 1039            1             0
# 1040            1             0
# 1041            1             0
# 1042            1             0
# 1043            1             0
#
# [1044 rows x 59 columns]

# %% [markdown]
# ### Transformations

# %% [markdown]
# ### Data Quality Reports

# %% [markdown]
# ### Selecting Features
